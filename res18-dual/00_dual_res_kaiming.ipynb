# %%
# %load_ext autoreload
# %autoreload 2

# %matplotlib inline

# %%
from geoloader00 import *

# %% [markdown]
# ## Create a dataframe with labels

# %%
city_imgs = AerialCity('atlanta')
df, n_matches = city_imgs.create_df()
df.head()
# Out:
# ['all_sat_LLAHTR', 'all_uav_LLAHTR', 'all_uav_xyzHTR', 'match_array_40', 'sat300_image_paths', 'uav_image_paths']
#                           uav                             sat  label  is_valid
# 0  train/atlanta/uav/uav0.png   train/atlanta/sat300/sat0.png      1     False
# 1  train/atlanta/uav/uav0.png  train/atlanta/sat300/sat10.png      1     False
# 2  train/atlanta/uav/uav0.png  train/atlanta/sat300/sat15.png      1     False
# 3  train/atlanta/uav/uav1.png   train/atlanta/sat300/sat1.png      1     False
# 4  train/atlanta/uav/uav1.png  train/atlanta/sat300/sat28.png      1     False

# %%
df[n_matches-5:n_matches+5]
# Out:
#                                 uav                               sat  label  \
# 3891  train/atlanta/uav/uav2074.png  train/atlanta/sat300/sat2074.png      1
# 3892  train/atlanta/uav/uav2075.png  train/atlanta/sat300/sat2034.png      1
# 3893  train/atlanta/uav/uav2075.png  train/atlanta/sat300/sat2075.png      1
# 3894  train/atlanta/uav/uav2076.png  train/atlanta/sat300/sat2076.png      1
# 3895  train/atlanta/uav/uav2077.png  train/atlanta/sat300/sat2077.png      1
# 3896     train/atlanta/uav/uav0.png  train/atlanta/sat300/sat1740.png      0
# 3897     train/atlanta/uav/uav0.png  train/atlanta/sat300/sat1640.png      0
# 3898     train/atlanta/uav/uav0.png  train/atlanta/sat300/sat1011.png      0
# 3899     train/atlanta/uav/uav1.png   train/atlanta/sat300/sat274.png      0
# 3900     train/atlanta/uav/uav1.png  train/atlanta/sat300/sat1727.png      0
#
#       is_valid
# 3891      True
# 3892      True
# 3893      True
# 3894      True
# 3895      True
# 3896     False
# 3897     False
# 3898     False
# 3899     False
# 3900     False

# %% [markdown]
# ## Create dataset
# Images are normalized internally. Satellite images are normalized with `(mean,std)` of satellite images, whereas uav images are normalized with `(mean,std)` of uav images.

# %%
train_ds, valid_ds = get_ds(df)

# %%
# dataset index, image-vs-label index, uav-vs-sat index
train_ds[0][0][0].shape # 0-1
# Out:
# torch.Size([3, 224, 224])

# %%
show_ex(train_ds,rows=2, shuffle=True)

# %%
bs = 24
train_dl = DataLoader(train_ds, batch_size=bs, shuffle=True)
valid_dl = DataLoader(valid_ds, batch_size=bs, shuffle=False)
data = DataBunch(train_dl, valid_dl)

# %%
GEres18 = models.resnet18(pretrained = False) # resnets are initialized with kaiming_normal
GMres18 = models.resnet18(pretrained = False)
class Identity(nn.Module):
    def __init__(self):
        super(Identity, self).__init__()
    def forward(self, x):
        return x
GEres18.fc = Identity()
GMres18.fc = Identity()

class DualResnet18(nn.Module):
    def __init__(self):
        super(DualResnet18, self).__init__()
        self.GE = GEres18
        self.GM = GMres18
    def forward(self, img1, img2):
        o1 = self.GE(img1)
        o2 = self.GM(img2)
        output = torch.norm(o1-o2, p=2, dim=1)
        return output

arch = DualResnet18()
arch = arch.to('cuda')

# %% [markdown]
# ### Contrastive Loss Function

# %%
def loss_contrastive(euclidean_distance, label_batch):
    margin = 100
    loss = torch.mean( (label_batch) * torch.pow(euclidean_distance, 2) +
                    (1-label_batch) * torch.pow(torch.clamp(margin - euclidean_distance, min=0.0), 2))
    return loss

# %% [markdown]
# ## Get, Set, GO Train!!!

# %%
learn = Learner(data, arch, loss_func=loss_contrastive)

# %%
learn.unfreeze()
learn.lr_find()
learn.recorder.plot(suggestion=True)
# Out:
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='0' class='' max='1', style='width:300px; height:20px; vertical-align: middle;'></progress>
#       0.00% [0/1 00:00<00:00]
#     </div>
#
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: left;">
#       <th>epoch</th>
#       <th>train_loss</th>
#       <th>valid_loss</th>
#       <th>time</th>
#     </tr>
#   </thead>
#   <tbody>
#   </tbody>
# </table><p>
#
#     <div>
#         <style>
#             /* Turns off some styling */
#             progress {
#                 /* gets rid of default border in Firefox and Opera. */
#                 border: none;
#                 /* Needs to be in here for Safari polyfill so background images work as expected. */
#                 background-size: auto;
#             }
#             .progress-bar-interrupted, .progress-bar-interrupted::-webkit-progress-bar {
#                 background: #F44336;
#             }
#         </style>
#       <progress value='99' class='' max
td>
#     </tr>
#     <tr>
#       <td>44</td>
#       <td>1729.695190</td>
#       <td>1915.955811</td>
#       <td>06:09</td>
#     </tr>
#     <tr>
#       <td>45</td>
#       <td>1676.473511</td>
#       <td>2409.282959</td>
#       <td>06:30</td>
#     </tr>
#     <tr>
#       <td>46</td>
#       <td>1735.294678</td>
#       <td>2220.705566</td>
#       <td>06:39</td>
#     </tr>
#     <tr>
#       <td>47</td>
#       <td>1740.495117</td>
#       <td>2297.979980</td>
#       <td>06:00</td>
#     </tr>
#     <tr>
#       <td>48</td>
#       <td>1725.327881</td>
#       <td>1739.558228</td>
#       <td>05:55</td>
#     </tr>
#     <tr>
#       <td>49</td>
#       <td>1680.645874</td>
#       <td>2124.893066</td>
#       <td>06:03</td>
#     </tr>
#     <tr>
#       <td>50</td>
#       <td>1657.334717</td>
#       <td>2268.730713</td>
#       <td>05:57</td>
#     </tr>
#     <tr>
#       <td>51</td>
#       <td>1714.578491</td>
#       <td>2199.268066</td>
#       <td>06:22</td>
#     </tr>
#     <tr>
#       <td>52</td>
#       <td>1677.975342</td>
#       <td>2866.968506</td>
#       <td>06:43</td>
#     </tr>
#     <tr>
#       <td>53</td>
#       <td>1636.018799</td>
#       <td>2366.600098</td>
#       <td>05:59</td>
#     </tr>
#     <tr>
#       <td>54</td>
#       <td>1693.920654</td>
#       <td>3227.233398</td>
#       <td>06:08</td>
#     </tr>
#     <tr>
#       <td>55</td>
#       <td>1604.467285</td>
#       <td>4108.645996</td>
#       <td>06:04</td>
#     </tr>
#     <tr>
#       <td>56</td>
#       <td>1608.713257</td>
#       <td>1876.429688</td>
#       <td>06:09</td>
#     </tr>
#     <tr>
#       <td>57</td>
#       <td>1649.335083</td>
#       <td>2896.364014</td>
#       <td>06:15</td>
#     </tr>
#     <tr>
#       <td>58</td>
#       <td>1664.332764</td>
#       <td>1829.736694</td>
#       <td>06:01</td>
#     </tr>
#     <tr>
#       <td>59</td>
#       <td>1689.815918</td>
#       <td>2630.723877</td>
#       <td>06:28</td>
#     </tr>
#     <tr>
#       <td>60</td>
#       <td>1581.193848</td>
#       <td>1884.520874</td>
#       <td>06:07</td>
#     </tr>
#     <tr>
#       <td>61</td>
#       <td>1526.637939</td>
#       <td>1619.549072</td>
#       <td>06:19</td>
#     </tr>
#     <tr>
#       <td>62</td>
#       <td>1667.034790</td>
#       <td>3049.143066</td>
#       <td>06:15</td>
#     </tr>
#     <tr>
#       <td>63</td>
#       <td>1518.527344</td>
#       <td>2005.258179</td>
#       <td>06:40</td>
#     </tr>
#     <tr>
#       <td>64</td>
#       <td>1578.669678</td>
#       <td>2003.811401</td>
#       <td>06:18</td>
#     </tr>
#     <tr>
#       <td>65</td>
#       <td>1586.313110</td>
#       <td>1859.348999</td>
#       <td>06:21</td>
#     </tr>
#     <tr>
#       <td>66</td>
#       <td>1559.351562</td>
#       <td>2064.738525</td>
#       <td>06:50</td>
#     </tr>
#     <tr>
#       <td>67</td>
#       <td>1526.157471</td>
#       <td>1738.691772</td>
#       <td>06:17</td>
#     </tr>
#     <tr>
#       <td>68</td>
#       <td>1558.645508</td>
#       <td>1969.856934</td>
#       <td>06:10</td>
#     </tr>
#     <tr>
#       <td>69</td>
#       <td>1506.263062</td>
#       <td>1738.203735<
# Better model found at epoch 0 with valid_loss value: 2050.404296875.
# Better model found at epoch 1 with valid_loss value: 1898.3077392578125.
# Better model found at epoch 10 with valid_loss value: 1837.341064453125.
# Better model found at epoch 18 with valid_loss value: 1717.34228515625.
# Better model found at epoch 34 with valid_loss value: 1699.279296875.
# Better model found at epoch 61 with valid_loss value: 1619.549072265625.

# %%
learn.recorder.plot_losses()

# %%
learn.recorder.plot_lr(show_moms=True)

# %%
learn.save('00_dual_res_kaiming')

# %% [markdown]
# ## Plot Histograms

# %%
from tqdm.notebook import tqdm

# %%
arch = learn.model
arch.eval()
def histo(dl, dset):
    matdist, nmatdist = [], []
    with tqdm(total=len(dl)) as progress_bar:
        for xb,yb in dl:
            imuav, imsat = xb[0].cuda(), xb[1].cuda()
            eucd = arch(imuav, imsat)
            mask0 = (yb==0)
            mask1 = (yb==1)
            nmatdist.extend(eucd[mask0].cpu().detach().numpy())
            matdist. extend(eucd[mask1].cpu().detach().numpy())
        progress_bar.update(1) # update progress

    mathist  = plt.hist( matdist, range(int(np.ceil(max( matdist)))), label = 'matching pairs', alpha = 0.7)
    nmathist = plt.hist(nmatdist, range(int(np.ceil(max(nmatdist)))), label = 'non-matching pairs', alpha = 0.7)
    plt.legend(loc='best')
    plt.title(dset + ' data')
    plt.xlabel('Distance between image pairs')
    plt.show()

# %%
histo(train_dl, 'train')
# Out:
# HBox(children=(FloatProgress(value=0.0, max=260.0), HTML(value='')))

# %%
histo(valid_dl, 'valid')
# Out:
# HBox(children=(FloatProgress(value=0.0, max=65.0), HTML(value='')))
